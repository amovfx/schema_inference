# %%
# %env OPENAI_API_KEY="Your api key here"
# Out:
# env: OPENAI_API_KEY=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

# %%
from pprint import pprint
import pandas as pd
import nest_asyncio
from model import llm

from langchain_core.documents import Document

nest_asyncio.apply()

# %% [markdown]
# # Generate stories from a similar structure.

# %%
prompts = ["Generate a description of a person and their background of a person doing person things."]*5
stories = await llm.with_config(
    configurable={"temperature": 2, "model": "gpt-3.5-turbo"}
).abatch(prompts)
stories
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/andrew/git/schema_inference/app/services/schema_inference/example.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/Users/andrew/git/schema_inference/app/services/schema_inference/example.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> prompts = ["Generate a description of a person and their background of a person doing person things."]*5
# ----> <a href='vscode-notebook-cell:/Users/andrew/git/schema_inference/app/services/schema_inference/example.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> stories = await llm.with_config(
#       <a href='vscode-notebook-cell:/Users/andrew/git/schema_inference/app/services/schema_inference/example.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a>     configurable={"temperature": 2, "model": "gpt-3.5-turbo"}
#       <a href='vscode-notebook-cell:/Users/andrew/git/schema_inference/app/services/schema_inference/example.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a> ).abatch(prompts)
#       <a href='vscode-notebook-cell:/Users/andrew/git/schema_inference/app/services/schema_inference/example.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a> stories
#
# File ~/anaconda3/envs/schema_inference/lib/python3.11/site-packages/langchain_core/runnables/base.py:1086, in Runnable.with_config(self, config, **kwargs)
#    1077 def with_config(
#    1078     self,
#    1079     config: Optional[RunnableConfig] = None,
#    1080     # Sadly Unpack is not well supported by mypy so this will have to be untyped
#    1081     **kwargs: Any,
#    1082 ) -> Runnable[Input, Output]:
#    1083     """
#    1084     Bind config to a Runnable, returning a new Runnable.
#    1085     """
# -> 1086     return RunnableBinding(
#    1087         bound=self,
#    1088         config=cast(
#    1089             RunnableConfig,
#    1090             {**(config or {}), **kwargs},
#    1091         ),  # type: ignore[misc]
#    1092         kwargs={},
#    1093     )
#
# File ~/anaconda3/envs/schema_inference/lib/python3.11/site-packages/langchain_core/runnables/base.py:3988, in RunnableBindingBase.__init__(self, bound, kwargs, config, config_factories, custom_input_type, custom_output_type, **other_kwargs)
#    3986     for key in configurable:
#    3987         if key not in allowed_keys:
# -> 3988             raise ValueError(
#    3989                 f"Configurable key '{key}' not found in runnable with"
#    3990                 f" config keys: {allowed_keys}"
#    3991             )
#    3992 super().__init__(
#    3993     bound=bound,
#    3994     kwargs=kwargs or {},
#    (...)
#    3999     **other_kwargs,
#    4000 )
#
# ValueError: Configurable key 'temperature' not found in runnable with config keys: {'llm_model_name', 'llm_temperature'}

# %%
documents = [Document(text.content) for text in stories]

# %% [markdown]
# # Schema Extractions

# %%
from chains import create_schema_inference_parser, extract_schema
from outputparser import SchemaInferenceParser

# %% [markdown]
# ##### Extracting an implicit schema from the documents. The llm will discover the structure.

# %%
output_parser_model = await create_schema_inference_parser(documents)
pprint(output_parser_model)
# Out:
# {'fields': [{'description': 'The age of the person',
#              'name': 'age',
#              'type': 'int'},
#             {'description': 'The profession of the person',
#              'name': 'profession',
#              'type': 'str'},
#             {'description': 'A list of hobbies the person enjoys',
#              'name': 'hobbies',
#              'type': 'List[str]'},
#             {'description': 'A list of personal qualities',
#              'name': 'qualities',
#              'type': 'List[str]'},
#             {'description': 'Belief that small acts of kindness can make a big '
#                             'difference',
#              'name': 'belief_in_kindness',
#              'type': 'bool'},
#             {'description': "The individual's background including education "
#                             'and professional experience.',
#              'name': 'background',
#              'type': 'str'},
#             {'description': "A list of the individual's interests and hobbies.",
#              'name': 'interests',
#              'type': 'List[str]'},
#             {'description': 'The country the individual originally comes from.',
#              'name': 'origin',
#              'type': 'str'},
#             {'description': 'The current high-ranking position the individual '
#                             'holds.',
#              'name': 'currentRole',
#              'type': 'str'},
#             {'description': 'List of personality traits of the individual.',
#              'name': 'personalityTraits',
#              'type': 'List[str]'},
#             {'description': "The individual's aspirations and what they are "
#                             'striving to achieve.',
#              'name': 'goals',
#              'type': 'str'},
#             {'description': 'The birthplace of the individual',
#              'name': 'birthplace',
#              'type': 'str'},
#             {'description': "Information about the individual's family",
#              'name': 'family_background',
#              'type': 'str'},
#             {'description': "The individual's highest level of education",
#              'name': 'education',
#              'type': 'str'},
#             {'description': 'The city where the individual currently resides',
#              'name': 'current_city',
#              'type': 'str'},
#             {'description': "The individual's current occupation and industry",
#              'name': 'career',
#              'type': 'str'},
#             {'description': "The frequency of visits to the individual's "
#                             'family',
#              'name': 'family_visits',
#              'type': 'str'},
#             {'description': "A list of the individual's personal traits",
#              'name': 'personal_traits',
#              'type': 'List[str]'},
#             {'description': 'The current occupation of the individual',
#              'name': 'occupation',
#              'type': 'str'},
#             {'description': 'A list of character traits of the individual',
#              'name': 'character_traits',
#              'type': 'List[str]'},
#             {'description': 'The size of the hometown',
#              'name': 'hometown_size',
#              'type': 'str'},
#             {'description': 'The highest level of education achieved',
#              'name': 'education_level',
#              'type': 'str'},
#             {'description': 'Type of volunteer work the person engages in',
#              'name': 'volunteer_work',
#              'type': 'str'},
#             {'description': "Description of the person's work ethic",
#              'name': 'work_ethic',
#              'type': 'str'},
#             {'description': 'Whether the person has a strong sense of '
#                             'gratitude',
#              'name': 'sense_of_gratitude',
#              'type': 'bool'}],
#  'name': 'UserProfile'}

# %% [markdown]
# ##### You can give it some guidance to isolate specific information.

# %%
output_parser_model_guided = await create_schema_inference_parser(
    documents, "From this data, only extract name, age, and interests"
)

# %%
pprint(output_parser_model_guided)
# Out:
# {'fields': [{'description': 'The name of the person',
#              'name': 'name',
#              'type': 'str'},
#             {'description': 'The age of the person',
#              'name': 'age',
#              'type': 'int'},
#             {'description': 'A list of interests of the person',
#              'name': 'interests',
#              'type': 'List[str]'}],
#  'name': 'UserProfile'}

# %% [markdown]
# ##### This is a good place to edit the schema to your liking.

# %%
output_parser_model_guided['fields'].pop(-1)
output_parser_model_guided
# Out:
# {'name': 'UserProfile',
#  'fields': [{'name': 'name',
#    'type': 'str',
#    'description': 'The name of the person'},
#   {'name': 'age', 'type': 'int', 'description': 'The age of the person'}]}

# %% [markdown]
# # Create parser from model

# %%
parser = SchemaInferenceParser.create_infered_json_parser(output_parser_model)

# %%
results = await extract_schema(documents, parser)
pprint(results)
# Out:
# [{'age': 35,
#   'background': 'grew up in a small town in the Midwest, worked hard to put '
#                 'herself through college and eventually land her dream job in '
#                 'the city',
#   'belief_in_kindness': None,
#   'birthplace': None,
#   'career': 'marketing',
#   'character_traits': ['kind', 'witty', 'determined'],
#   'currentRole': None,
#   'current_city': None,
#   'education': 'college',
#   'education_level': 'college',
#   'family_background': 'comes from humble beginnings',
#   'family_visits': None,
#   'goals': None,
#   'hobbies': ['practicing yoga',
#               'exploring new restaurants',
#               'volunteering at a local animal shelter'],
#   'hometown_size': 'small',
#   'interests': ['yoga', 'exploring new restaurants', 'volunteering'],
#   'occupation': 'marketing executive',
#   'origin': None,
#   'personal_traits': ['kind heart', 'quick wit', 'determination'],
#   'personalityTraits': ['kind', 'witty', 'determined'],
#   'profession': 'marketing executive',
#   'qualities': ['kind heart', 'quick wit', 'unwavering determination'],
#   'sense_of_gratitude': True,
#   'volunteer_work': 'local animal shelter',
#   'work_ethic': 'strong work ethic'},
#  {'age': 35,
#   'background': 'Born and raised in a small town in the Midwest, attended '
#                 'college in a nearby city studying marketing and graduated '
#                 'with honors. Moved to Chicago to pursue a career in '
#                 'advertising, quickly worked up the ranks at a top agency.',
#   'belief_in_kindness': None,
#   'birthplace': None,
#   'career': 'Advertising',
#   'character_traits': ['creative',
#                        'detail-oriented',
#                        'driven',
#                        'ambitious',
#                        'loyal',
#                        'loving',
#                        'dedicated',
#                        'positive',
#                        'adventurous'],
#   'currentRole': 'respected account executive',
#   'current_city': 'Chicago',
#   'education': 'Graduated with honors in marketing',
#   'education_level': 'college graduate',
#   'family_background': 'Comes from a close-knit family, with two younger '
#                        'siblings and parents who have been married for over 40 '
#                        'years.',
#   'family_visits': 'Regularly travels back home to visit her parents and '
#                    'siblings.',
#   'goals': None,
#   'hobbies': ['practicing yoga',
#               'going for runs along the lakefront',
#               'cooking',
#               "exploring the city's vibrant art scene"],
#   'hometown_size': 'small',
#   'interests': ['yoga', 'running', 'cooking', 'art', 'brunch with friends'],
#   'occupation': 'account executive',
#   'origin': None,
#   'personal_traits': ['creative',
#                       'detail-oriented',
#                       'driven',
#                       'ambitious',
#                       'loyal',
#                       'loving',
#                       'dedicated',
#                       'positive',
#                       'adventurous'],
#   'personalityTraits': ['creative',
#                         'detail-oriented',
#                         'driven',
#                         'ambitious',
#                         'loyal',
#                         'loving',
#                         'dedicated',
#                         'positive',
#                         'adventurous'],
#   'profession': 'account executive',
#   'qualities': ['creativity',
#                 'attention to detail',
#                 'driven',
#                 'ambitious',
#                 'loyal friend',
#                 'loving daughter',
#                 'dedicated professional',
#                 'positive attitude',
#                 'sense of adventure'],
#   'sense_of_gratitude': None,
#   'volunteer_work': None,
#   'work_ethic': 'strong work ethic and sense of determination'},
#  {'age': 35,
#   'background': 'Grew up in a small town in the Midwest, raised by a single '
#                 'mother. Earned a degree in social work and now works as a '
#                 'counselor at a local shelter for homeless youth.',
#   'belief_in_kindness': True,
#   'birthplace': None,
#   'career': 'Counselor at a local shelter for homeless youth',
#   'character_traits': ['kind-hearted',
#                        'hardworking',
#                        'compassionate',
#                        'resilient',
#                        'positive',
#                        'determined'],
#   'currentRole': None,
#   'current_city': None,
#   'education': 'Degree in social work',
#   'education_level': 'College degree',
#   'family_background': 'Raised by a single mother who worked multiple jobs to '
#                        'provide for her and her siblings.',
#   'family_visits': None,
#   'goals': None,
#   'hobbies': ['volunteering at a local animal shelter',
#               'spending time with her two rescue dogs',
#               'hiking',
#               'fitness',
#               'going to the gym',
#               'running in the park'],
#   'hometown_size': 'small',
#   'interests': ['volunteering', 'animal welfare', 'hiking', 'fitness'],
#   'occupation': 'Counselor',
#   'origin': None,
#   'personal_traits': ['kind-hearted',
#                       'hardworking',
#                       'compassionate',
#                       'resilient',
#                       'positive',
#                       'determined'],
#   'personalityTraits': ['kind-hearted',
#                         'hardworking',
#                         'compassionate',
#                         'resilient',
#                         'positive',
#                         'determined'],
#   'profession': 'counselor',
#   'qualities': ['kind-hearted',
#                 'hardworking',
#                 'compassionate',
#                 'resilient',
#                 'positive',
#                 'determined'],
#   'sense_of_gratitude': True,
#   'volunteer_work': 'Local animal shelter',
#   'work_ethic': 'Dedicated to making a positive impact on the world'},
#  {'age': 28,
#   'background': 'Graduated from college with a degree in social work, began '
#                 'working at a local non-profit organization that provides '
#                 'support to at-risk youth.',
#   'belief_in_kindness': True,
#   'birthplace': None,
#   'career': 'working at a local non-profit organization supporting at-risk '
#             'youth',
#   'character_traits': ['compassion', 'selflessness'],
#   'currentRole': None,
#   'current_city': None,
#   'education': 'college degree in social work',
#   'education_level': 'college degree',
#   'family_background': None,
#   'family_visits': None,
#   'goals': None,
#   'hobbies': ['volunteering at a local animal shelter',
#               'walking dogs',
#               'socializing with animals',
#               'spending time outdoors',
#               'hiking',
#               'exploring nature trails'],
#   'hometown_size': 'small town',
#   'interests': ['volunteering',
#                 'outdoors',
#                 'hiking',
#                 'exploring nature trails',
#                 'animal welfare'],
#   'occupation': 'social worker',
#   'origin': None,
#   'personal_traits': ['empathetic',
#                       'willingness to help',
#                       'dedicated',
#                       'positive',
#                       'hopeful'],
#   'personalityTraits': ['empathetic', 'positive', 'hopeful'],
#   'profession': 'social work',
#   'qualities': ['empathetic',
#                 'willingness to help',
#                 'dedicated',
#                 'positive',
#                 'hopeful'],
#   'sense_of_gratitude': None,
#   'volunteer_work': 'volunteering at a local animal shelter',
#   'work_ethic': None},
#  {'age': None,
#   'background': 'Originally from Brazil, moved to the United States to pursue '
#                 'dreams of becoming a successful businesswoman. Holds a degree '
#                 'in finance from a top university and now holds a high-ranking '
#                 'position at a prestigious investment firm.',
#   'belief_in_kindness': None,
#   'birthplace': None,
#   'career': 'businesswoman in the finance sector',
#   'character_traits': ['vibrant',
#                        'charismatic',
#                        'warm',
#                        'welcoming',
#                        'driven',
#                        'ambitious',
#                        'positive attitude',
#                        'determination'],
#   'currentRole': 'high-ranking position at a prestigious investment firm',
#   'current_city': None,
#   'education': 'degree in finance from a top university',
#   'education_level': 'university degree',
#   'family_background': None,
#   'family_visits': None,
#   'goals': 'striving to be the best version of herself, both mentally and '
#            'physically',
#   'hobbies': ['running',
#               'hitting the gym',
#               'participating in yoga classes',
#               'experimenting with new healthy recipes'],
#   'hometown_size': None,
#   'interests': ['fitness', 'wellness', 'healthy recipes'],
#   'occupation': 'businesswoman',
#   'origin': 'Brazil',
#   'personal_traits': ['vibrant',
#                       'charismatic',
#                       'warm',
#                       'welcoming',
#                       'driven',
#                       'ambitious',
#                       'positive attitude',
#                       'determination'],
#   'personalityTraits': ['vibrant',
#                         'charismatic',
#                         'driven',
#                         'ambitious',
#                         'positive attitude',
#                         'determination'],
#   'profession': 'businesswoman',
#   'qualities': ['warm', 'welcoming', 'willing to lend a helping hand'],
#   'sense_of_gratitude': None,
#   'volunteer_work': None,
#   'work_ethic': None}]

# %%
df = pd.DataFrame(results)
df.head()
# Out:
#     age           profession  \
# 0  35.0  marketing executive
# 1  35.0    account executive
# 2  35.0            counselor
# 3  28.0          social work
# 4   NaN        businesswoman
#
#                                              hobbies  \
# 0  [practicing yoga, exploring new restaurants, v...
# 1  [practicing yoga, going for runs along the lak...
# 2  [volunteering at a local animal shelter, spend...
# 3  [volunteering at a local animal shelter, walki...
# 4  [running, hitting the gym, participating in yo...
#
#                                            qualities belief_in_kindness  \
# 0  [kind heart, quick wit, unwavering determination]               None
# 1  [creativity, attention to detail, driven, ambi...               None
# 2  [kind-hearted, hardworking, compassionate, res...               True
# 3  [empathetic, willingness to help, dedicated, p...               True
# 4  [warm, welcoming, willing to lend a helping hand]               None
#
#                                           background  \
# 0  grew up in a small town in the Midwest, worked...
# 1  Born and raised in a small town in the Midwest...
# 2  Grew up in a small town in the Midwest, raised...
# 3  Graduated from college with a degree in social...
# 4  Originally from Brazil, moved to the United St...
#
#                                            interests  origin  \
# 0    [yoga, exploring new restaurants, volunteering]    None
# 1  [yoga, running, cooking, art, brunch with frie...    None
# 2    [volunteering, animal welfare, hiking, fitness]    None
# 3  [volunteering, outdoors, hiking, exploring nat...    None
# 4               [fitness, wellness, healthy recipes]  Brazil
#
#                                          currentRole  \
# 0                                               None
# 1                        respected account executive
# 2                                               None
# 3                                               None
# 4  high-ranking position at a prestigious investm...
#
#                                    personalityTraits  ...  \
# 0                          [kind, witty, determined]  ...
# 1  [creative, detail-oriented, driven, ambitious,...  ...
# 2  [kind-hearted, hardworking, compassionate, res...  ...
# 3                    [empathetic, positive, hopeful]  ...
# 4  [vibrant, charismatic, driven, ambitious, posi...  ...
#
#                                               career  \
# 0                                          marketing
# 1                                        Advertising
# 2    Counselor at a local shelter for homeless youth
# 3  working at a local non-profit organization sup...
# 4                businesswoman in the finance sector
#
#                                        family_visits  \
# 0                                               None
# 1  Regularly travels back home to visit her paren...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                      personal_traits           occupation  \
# 0             [kind heart, quick wit, determination]  marketing executive
# 1  [creative, detail-oriented, driven, ambitious,...    account executive
# 2  [kind-hearted, hardworking, compassionate, res...            Counselor
# 3  [empathetic, willingness to help, dedicated, p...        social worker
# 4  [vibrant, charismatic, warm, welcoming, driven...        businesswoman
#
#                                     character_traits hometown_size  \
# 0                          [kind, witty, determined]         small
# 1  [creative, detail-oriented, driven, ambitious,...         small
# 2  [kind-hearted, hardworking, compassionate, res...         small
# 3                         [compassion, selflessness]    small town
# 4  [vibrant, charismatic, warm, welcoming, driven...          None
#
#      education_level                          volunteer_work  \
# 0            college                    local animal shelter
# 1   college graduate                                    None
# 2     College degree                    Local animal shelter
# 3     college degree  volunteering at a local animal shelter
# 4  university degree                                    None
#
#                                           work_ethic sense_of_gratitude
# 0                                  strong work ethic               True
# 1       strong work ethic and sense of determination               None
# 2  Dedicated to making a positive impact on the w...               True
# 3                                               None               None
# 4                                               None               None
#
# [5 rows x 25 columns]

# %%
test = llm.with_config(configurable={"temperature": 2, "model": "gpt-3.5-turbo"})

# %%
test.config
# Out:
# {'configurable': {'temperature': 2, 'model': 'gpt-3.5-turbo'}}

# %%
from outputparser import SchemaInferenceParser, type_map

# %%
import json
type_map_str = json.dumps({k: k for k in type_map.keys()})
type_map_str
# Out:
# '{"str": "str", "int": "int", "float": "float", "bool": "bool", "List[str]": "List[str]", "List[int]": "List[int]", "List[float]": "List[float]", "List[bool]": "List[bool]", "List[dict]": "List[dict]"}'

# %%
for k in type_map.keys():
    type_map_str = type_map_str.replace(f': "k"', f': -')
type_map_str
# Out:
# '{"str": "str", "int": "int", "float": "float", "bool": "bool", "List[str]": "List[str]", "List[int]": "List[int]", "List[float]": "List[float]", "List[bool]": "List[bool]", "List[dict]": "List[dict]"}'

# %%
modified_string = (
    type_map_str.replace('": "', '": ').replace('", ', ', ').replace('"}', "}")
)

# %%
modified_string
# Out:
# '{"str": str, "int": int, "float": float, "bool": bool, "List[str]": List[str], "List[int]": List[int], "List[float]": List[float], "List[bool]": List[bool], "List[dict]": List[dict]}'
